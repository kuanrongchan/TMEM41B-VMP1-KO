# %%
import csv
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kuanrongchan/TMEM41B-VMP1-KO/main/Lipids_VMP1_TMEM41B_KO.csv',index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89 entries, FA(14:0) to Oleoylcarnitine (C18:1)
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WT_1         89 non-null     float64
#  1   WT_2         89 non-null     float64
#  2   WT_3         89 non-null     float64
#  3   VMP1KO_1     89 non-null     float64
#  4   VMP1KO_2     89 non-null     float64
#  5   VMP1KO_3     89 non-null     float64
#  6   TMEM41BKO_1  89 non-null     float64
#  7   TMEM41BKO_2  89 non-null     float64
#  8   TMEM41BKO_3  89 non-null     float64
# dtypes: float64(9)
# memory usage: 7.0+ KB
#                   WT_1          WT_2          WT_3      VMP1KO_1  \
# Lipid
# FA(14:0)  1.283642e+05  1.365266e+05  1.118855e+05  6.522439e+04
# FA(16:0)  3.037332e+06  3.108886e+06  2.450439e+06  1.808545e+06
#
#               VMP1KO_2      VMP1KO_3   TMEM41BKO_1   TMEM41BKO_2   TMEM41BKO_3
# Lipid
# ...

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

g = sns.clustermap(df, z_score=0, cmap="vlag", figsize=(10, 30), method='average', robust=True, cbar_kws={"ticks":[-1,0,1]})
